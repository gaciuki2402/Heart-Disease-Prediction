# %% [markdown]
# <a href="https://colab.research.google.com/github/gaciuki2402/Heart-Disease-Prediction/blob/main/Heart_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
import pandas as pd
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/CSV/heart_disease.csv")

# %%
data.drop(columns=["education"], inplace=True)
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4235  Female   48              1        20.0     NaN              no
# 4236  Female   44              1        15.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4235             0         0    248.0  131.0   72.0  22.00       84.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4233     86.0           yes
# 4234     68.0            No
# 4235     86.0            No
# 4236      NaN            No
# 4237    107.0            No
#
# [4238 rows x 15 columns]

# %%
data.dropna(inplace=True)
data['Gender'] = data['Gender'].replace(['Male','Female'],[1,0])
data['prevalentStroke'] = data['prevalentStroke'].replace(['yes','no'],[1,0])
data.prevalentStroke.unique()
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4231     81.0            No
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0            No
# 4237    107.0            No
#
# [3749 rows x 15 columns]

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0       Male   39              0         0.0     0.0                0
# 1     Female   46              0         0.0     0.0                0
# 2       Male   48              1        20.0     0.0                0
# 3     Female   61              1        30.0     0.0                0
# 4     Female   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231    Male   58              0         0.0     0.0                0
# 4232    Male   68              0         0.0     0.0                0
# 4233    Male   50              1         1.0     0.0                0
# 4234    Male   51              1        43.0     0.0                0
# 4237  Female   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4231     81.0            No
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0            No
# 4237    107.0            No
#
# [3749 rows x 15 columns]

# %%
data['Heart_ stroke'].unique()
# Out:
# array(['No', 'yes'], dtype=object)

# %%
data["Heart_ stroke"] = data["Heart_ stroke"].replace(["No","yes"],[0,1])
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose  Heart_ stroke
# 0        77.0              0
# 1        76.0              0
# 2        70.0              0
# 3       103.0              1
# 4        85.0              0
# ...       ...            ...
# 4231     81.0              0
# 4232     79.0              1
# 4233     86.0              1
# 4234     68.0              0
# 4237    107.0              0
#
# [3749 rows x 15 columns]

# %%
data_input = data.drop(columns=["Heart_ stroke"])
data_output = data['Heart_ stroke']
data_output.value_counts()
# Out:
# 0    3177
# 1     572
# Name: Heart_ stroke, dtype: int64

# %%
# resampling of the dataset
# SMOTE will balance the dataset
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
data_input, data_output = sm.fit_resample(data_input, data_output.ravel())

# %%
np.unique(data_output, return_counts=True)
# Out:
# (array([0, 1]), array([3177, 3177]))

# %%
# splitting the data into train data and test data
